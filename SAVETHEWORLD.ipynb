# %% [markdown]
# # SAVE THE WORLD

# %% [markdown]
# Over the past 10 years, a mysterious illness has infiltrated the population of Eurasia. Although we thought it was localized, now a great portion of the population of Canada has contracted or will contract the illness. A cure has still not been found but we do have some treatement that greatly reduce casualties, Justin Trudeau has named you in charge of deployment of ressources. Since a a real cure is still 5 years away, your task is to minimze the canadian deaths over the next five years.

# %% [markdown]
# Here's what you need to know:
#
# - The only way to give the population the treatement is by a consultation with a doctor.
# - Studies has also shown that death probabilities are as below.

# %%
import pandas as pd

prob = pd.read_excel('./prob.xlsx')
prob
# Out:
#   General_Health  Within the past year  Within the past 2 years  \
# 0      Excellent                  0.01                     0.08
# 1      Very Good                  0.03                     0.14
# 2           Good                  0.05                     0.23
# 3           Fair                  0.10                     0.33
# 4           Poor                  0.20                     0.40
#
#    Within the past 5 years  5 or more years ago
# 0                     0.17                  0.3
# 1                     0.34                  0.5
# 2                     0.46                  0.7
# 3                     0.56                  0.8
# 4                     0.70                  0.9

# %% [markdown]
# Unfortunetly, both of these variable are not observed (test set). Here's the data that you have to work with.

# %%
data = pd.read_csv('./CVD_cleaned.csv')
data
# Out:
#        General_Health                  Checkup Exercise Heart_Disease  \
# 0                Poor  Within the past 2 years       No            No
# 1           Very Good     Within the past year       No           Yes
# 2           Very Good     Within the past year      Yes            No
# 3                Poor     Within the past year      Yes           Yes
# 4                Good     Within the past year       No            No
# ...               ...                      ...      ...           ...
# 308849      Very Good     Within the past year      Yes            No
# 308850           Fair  Within the past 5 years      Yes            No
# 308851      Very Good      5 or more years ago      Yes            No
# 308852      Very Good     Within the past year      Yes            No
# 308853      Excellent     Within the past year      Yes            No
#
#        Skin_Cancer Other_Cancer Depression  \
# 0               No           No         No
# ...

# %% [markdown]
# Final detail, we only have test_size/5 doctor consultation avialble per year.
